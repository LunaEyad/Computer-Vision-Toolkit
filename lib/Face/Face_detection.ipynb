# %%
# Uploading files

from google.colab import files
# uploaded = files.upload()
img_path1 = 'image_test.jpeg'
img_path2 = "Lenna_512.png"

# %% [markdown]
# # Face detection using CV

# %%
import cv2

img = cv2.imread(img_path2)
img.shape # represent the picture’s height, width, and channels
# Out:
# (512, 512, 3)

# %%
#To improve computational efficiency, we first need to convert this image to grayscale before performing face detection on it
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (512, 512)

# %%
#Let’s load the pre-trained Haar Cascade classifier that is built into OpenCV:
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
# preform face detection
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40)
)

#scaleFactor=1.1 ->  reduce the image size by 10% -> easier computation

# %%
# Drawing a Bounding Box
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.imshow(img_rgb)
plt.axis('off')
plt.show()
